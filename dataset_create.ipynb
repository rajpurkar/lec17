# %%
import glob
import os
from PIL import Image

def check_image(path):
    try:
        Image.open(path)
        return True
    except:
        return False

imgs = [f for f in glob.glob("physionet.org/**", recursive=True) if os.path.isfile(f) and check_image(f)]
stemns = {img: os.path.basename(os.path.dirname(img)) for img in imgs}

# %%
import pandas as pd
# don't orient on index
img_df = pd.DataFrame.from_dict(stemns, orient='index')
# drop index
img_df.reset_index(inplace=True)
img_df.columns = ['path', 'study']
print(img_df)

# %%
txt_files = [f for f in glob.glob('files/p10/**', recursive=True) if os.path.isfile(f) and f.endswith('.txt')]

# open each text file and save in a dictionary
# key: filename
# value: list of lines
txts = {}
for txt_file in txt_files:
    with open(txt_file) as f:
        txts[os.path.splitext(os.path.basename(txt_file))[0]] = f.read()
print(next(iter(txts.items())))

# %%
# convert to pandas dataframe
import pandas as pd
df = pd.DataFrame.from_dict(txts, orient='index')
df.reset_index(inplace=True)
df.columns = ['study', 'report']
print(df)

# %%
def section_start(lines, section=' IMPRESSION'):
    """Finds line index that is the start of the section."""
    for idx, line in enumerate(lines):
        if line.startswith(section):
            return idx
    return -1

def extract_impressions(df):
    """Generates a csv containing report impressions."""
    df_imp = df.copy()
    for index, row in df_imp.iterrows():
        report = row['report'].splitlines()
        impression_idx = section_start(report)
        impression_and_findings_idx = section_start(report, section=' FINDINGS AND IMPRESSION:')
        seperator = ''
        if impression_idx != -1:
            impression = seperator.join(report[impression_idx:]).replace('IMPRESSION:', '').replace('\n', '').strip()
        elif impression_and_findings_idx != -1:
            impression = seperator.join(report[impression_and_findings_idx:]).replace('FINDINGS AND IMPRESSION:', '').replace('\n', '').strip()
        else:
            impression = ''

        df_imp.at[index,'report']= impression
    return df_imp

txt_df = extract_impressions(df)
txt_df

# %%
join_df = img_df.merge(txt_df, on='study', how='left')
# remove the 'path' column 
join_df.drop('study', axis=1, inplace=True)
# remove rows with empty reports
join_df['report'].replace('', pd.np.nan, inplace=True)
join_df.dropna(subset=['report'], inplace=True)
print(join_df)
# Out:
#                                                  path  \
# 0   physionet.org/files/mimic-cxr-jpg/2.0.0/files/...
# 1   physionet.org/files/mimic-cxr-jpg/2.0.0/files/...
# 2   physionet.org/files/mimic-cxr-jpg/2.0.0/files/...
# 3   physionet.org/files/mimic-cxr-jpg/2.0.0/files/...
# 4   physionet.org/files/mimic-cxr-jpg/2.0.0/files/...
# 5   physionet.org/files/mimic-cxr-jpg/2.0.0/files/...
# 6   physionet.org/files/mimic-cxr-jpg/2.0.0/files/...
# 7   physionet.org/files/mimic-cxr-jpg/2.0.0/files/...
# 8   physionet.org/files/mimic-cxr-jpg/2.0.0/files/...
# 9   physionet.org/files/mimic-cxr-jpg/2.0.0/files/...
# 52  physionet.org/files/mimic-cxr-jpg/2.0.0/files/...
# 53  physionet.org/files/mimic-cxr-jpg/2.0.0/files/...
# 54  physionet.org/files/mimic-cxr-jpg/2.0.0/files/...
# 55  physionet.org/files/mimic-cxr-jpg/2.0.0/files/...
#
#                                                report
# 0                   No acute cardiopulmonary process.
# 1                   No acute cardiopulmonary process.
# 2               No acute cardiopulmonary abnormality.
# 3               No acute cardiopulmonary abnormality.
# 4                     No acute intrathoracic process.
# 5                     No acute intrathoracic process.
# 6                   No acute cardiopulmonary process.
# 7   Focal consolidation at the left lung base, pos...
# 8   Focal consolidation at the left lung base, pos...
# 9   Focal consolidation at the left lung base, pos...
# 10                    No acute intrathoracic process.
# 11                    No acute intrathoracic process.
# 12      No evidence of acute cardiopulmonary process.
# 13      No evidence of acute cardiopulmonary process.
# 14      No evidence of acute cardiopulmonary process.
# 15  1. Low lung volumes and mild pulmonary vascula...
# 16  Increasing left lung opacification which may r...
# 17  Increasing left lung opacification which may r...
# 18                           Stable chest radiograph.
# 19                           Stable chest radiograph.
# 20  New nodular opacities within both upper lobes,...
# 21  New nodular opacities within both upper lobes,...
# 24  Innumerable pulmonary metastases.  Possible mi...
# 25  Compared to chest radiographs since ___, most ...
# 26  Compared to chest radiographs since ___, most ...
# 27  Right upper lobe pneumonia or mass.  However, ...
# 28            No radiographic evidence for pneumonia.
# 29            No radiographic evidence for pneumonia.
# 30  Mild pulmonary edema with superimposed left up...
# 31  Mild pulmonary edema with superimposed left up...
# 32                  No acute cardiopulmonary process.
# 33                  No acute cardiopulmonary process.
# 34  Interval resolution of previously seen mild pu...
# 35  Interval resolution of previously seen mild pu...
# 36  1. New mild pulmonary edema with persistent sm...
# 37  As compared to ___, the lung volumes have slig...
# 38  As compared to ___, the lung volumes have slig...
# 39  Tiny pleural effusions, new. Otherwise unremar...
# 40  Tiny pleural effusions, new. Otherwise unremar...
# 41                    No acute intrathoracic process.
# 42                    No acute intrathoracic process.
# 43                    No acute intrathoracic process.
# 44  The lung volumes are normal.  No evidence of T...
# 45  The lung volumes are normal.  No evidence of T...
# 46              No acute cardiopulmonary abnormality.
# 47              No acute cardiopulmonary abnormality.
# 48              No acute cardiopulmonary abnormality.
# 49  Mild perihilar prominence, suspected to repres...
# 50  Mild perihilar prominence, suspected to repres...
# 51                               Mild pulmonary edema
# 52                               Mild pulmonary edema
# 53                               Mild pulmonary edema
# 54  Mild left base atelectasis.  Otherwise, no acu...
# 55  Mild left base atelectasis.  Otherwise, no acu...
# /tmp/ipykernel_7908/3273492434.py:5: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#   join_df['report'].replace('', pd.np.nan, inplace=True)

# %%
join_df.to_csv('joined.csv', index=False)
